# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../data/sales_dataset.csv", parse_dates=["Order Date"])
df.head()
# Out:
#    Order ID                    Order Date   Product     Category Region  \
# 0     10001 2023-01-01 00:00:00.000000000     Mouse  Accessories   West
# 1     10002 2023-01-01 01:44:51.178235647   Monitor  Electronics   West
# 2     10003 2023-01-01 03:29:42.356471294  Keyboard  Electronics  North
# 3     10004 2023-01-01 05:14:33.534706941   Monitor  Accessories   West
# 4     10005 2023-01-01 06:59:24.712942588   Monitor  Accessories   West
#
#    Quantity  Price   Sales
# 0         4  48969  195876
# 1         5  49838  249190
# 2         5   9734   48670
# 3         5  42651  213255
# 4         4  34793  139172

# %%
df.shape
# Out:
# (5000, 8)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Product', 'Category', 'Region', 'Quantity',
#        'Price', 'Sales'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Order ID               int64
# Order Date    datetime64[ns]
# Product               object
# Category              object
# Region                object
# Quantity               int64
# Price                  int64
# Sales                  int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Order ID      0
# Order Date    0
# Product       0
# Category      0
# Region        0
# Quantity      0
# Price         0
# Sales         0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#             Order ID                     Order Date Product     Category  \
# count    5000.000000                           5000    5000         5000
# unique           NaN                            NaN       6            2
# top              NaN                            NaN  Laptop  Accessories
# freq             NaN                            NaN     870         2528
# mean    12500.500000            2023-07-02 00:00:00     NaN          NaN
# min     10001.000000            2023-01-01 00:00:00     NaN          NaN
# 25%     11250.750000            2023-04-02 00:00:00     NaN          NaN
# 50%     12500.500000  2023-07-02 00:00:00.000000256     NaN          NaN
# 75%     13750.250000            2023-10-01 00:00:00     NaN          NaN
# max     15000.000000            2023-12-31 00:00:00     NaN          NaN
# std      1443.520003                            NaN     NaN          NaN
#
#        Region     Quantity         Price          Sales
# count    5000  5000.000000   5000.000000    5000.000000
# unique      4          NaN           NaN            NaN
# top     North          NaN           NaN            NaN
# freq     1299          NaN           NaN            NaN
# mean      NaN     3.027200  30626.806800   92795.026200
# min       NaN     1.000000   1018.000000    1018.000000
# 25%       NaN     2.000000  16038.500000   35497.750000
# 50%       NaN     3.000000  30465.500000   72637.000000
# 75%       NaN     4.000000  45737.750000  138197.750000
# max       NaN     5.000000  59999.000000  299980.000000
# std       NaN     1.419318  17013.060938   72094.891442

# %%
print("Products:", df["Product"].unique())
print("Categories:", df["Category"].unique())
print("Regions:", df["Region"].unique())
df.to_csv("../data/sales_cleaned.csv", index=False)
# Out:
# Products: ['Mouse' 'Monitor' 'Keyboard' 'Headphones' 'Webcam' 'Laptop']
# Categories: ['Accessories' 'Electronics']
# Regions: ['West' 'North' 'South' 'East']
